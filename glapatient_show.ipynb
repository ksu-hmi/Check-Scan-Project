# %%
# %pylab inline
from PIL import Image
from matplotlib.pyplot import imshow
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('C:/Users/andtaylor/Pictures/HDisc.png')
imgplot = plt.imshow(img)
print('************************************************************')
print('Patient #234 = D. Stewart ')
print('Diagnois - Acute Glaucoma - Eye Drops and Glasses')
print ('Request User to submit')

print('************************************************************')
plt.show()
# Out:
# ************************************************************
# Patient #234 = D. Stewart
# Diagnois - Acute Glaucoma - Eye Drops and Glasses
# Request User to submit
# ************************************************************
